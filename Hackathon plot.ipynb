# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# df is a dataframe of size (# Participants x Trials)
df = pd.read_csv('all_policies.csv')
df
# Out:
#        Company    FRES   FKG  ASL  Predicted
# 0       amazon -176.89  32.2   58       2.26
# 1        apple   31.04  16.8   31       2.40
# 2          abc   -6.29  27.0   51       2.48
# 3     facebook   36.46  16.7   34       2.51
# 4       reddit   29.82  17.2   32       2.61
# 5    microsoft  -11.13  30.9   64       2.73
# 6      walmart -137.95  58.9  106       3.54
# 7       google   26.51  20.6   44       3.68
# 8         lyft   40.72  15.1   30       3.91
# 9         imdb    6.95  23.9   46       4.00
# 10      github   -2.67  23.5   39       4.21
# 11         ibm    1.78  25.9   52       4.34
# 12      lenovo  -19.05  27.7   47       4.79
# 13         ted  -19.79  32.1   64       4.83
# 14  dairyqueen   28.40  17.8   34       5.26

# %%
plt.scatter(df['Company'], df['Predicted'])
plt.xlabel("Companies")
plt.ylabel("Predicted Scores")
plt.xticks(rotation=45, ha="right")
# plt.figure(figsize=(1000,700))
fig = plt.gcf()
fig.set_size_inches(14, 8)
plt.show()
