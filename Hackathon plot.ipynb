# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# df is a dataframe of size (# Participants x Trials)
df = pd.read_csv('plot_data.csv')
df
# Out:
#                 Company  Score
# 0              Atlantic    1.0
# 1                  imdb    1.0
# 2       TheNewYorkTImes    1.0
# 3                   Vox    1.3
# 4          nbcuniversal    1.5
# 5               Esquire    1.5
# 6                Liquor    1.5
# 7              meredith    2.0
# 8              Sheknows    2.1
# 9                Google    2.1
# 10     neworleansonline    2.2
# 11               Amazon    2.3
# 12              Pornhub    2.3
# 13            instagram    2.3
# 14                style    2.5
# 15             Facebook    2.5
# 16                  mlb    2.5
# 17              ABCnews    2.6
# 18               Alipay    2.7
# 19          foodallergy    2.8
# 20             refrence    2.8
# 21               WeChat    2.9
# 22              netflix    3.0
# 23               reddit    3.0
# 24               Huawei    3.0
# 25       ashley madison    3.0
# 26              USA Gov    3.0
# 27              Alibaba    3.0
# 28                apple    3.0
# 29                Honda    3.2
# 30           Riot Games    3.3
# 31            UWaterloo    3.4
# 32  Minecraft Gamepedia    3.5
# 33            microsoft    3.5
# 34           Volkswagen    3.5
# 35         Steampowered    3.6
# 36                 ICBC    3.8
# 37                Baidu    3.9
# 38            AirCanada    4.0
# 39              tencent    4.0
# 40              youtube    4.0
# 41               GitHub    4.1
# 42               tiktok    4.2
# 43           livejasmin    4.5
# 44               Oracle    4.5
# 45                 Uber    4.7
# 46                Exxon    4.7
# 47               Paypal    4.8
# 48             linkedin    5.0

# %%
plt.scatter(df['Company'], df['Score'])
plt.xlabel("Companies")
plt.ylabel("Scores")
plt.xticks(rotation=45, ha="right")
# plt.figure(figsize=(1000,700))
fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.show()
